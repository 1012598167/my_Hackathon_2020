# %%
import pandas as pd

#ylk_formal=pd.read_excel('my_Hackathon_2020/自建语料库(与微软合作).xlsx',index_col=None)
ylk_formal=pd.read_excel('my_Hackathon_2020/疫战智能问答语料库-去重正式版v1.4.xlsx',index_col=None)
ylk_formal=ylk_formal.dropna(axis=0,how='all')

# %%
ylk_formal.tail(20)
# Out:
#         分类                        ...                                                                         答案
# 5769   NaN                        ...                                                                        NaN
# 5770   NaN                        ...                                                                        NaN
# 5771   NaN                        ...                                                                        NaN
# 5772   NaN                        ...                                                                        NaN
# 5773   NaN                        ...                                                                        NaN
# 5774  疫情相关                        ...                          此次引起新型肺炎的病毒为2019新型冠状病毒（2019-nCoV），目前认为新型冠状病毒的来...
# 5775   NaN                        ...                                                                        NaN
# ...

# %%
ylk_formal_cop=ylk_formal.copy()

# %%
new
# Out:
# Empty DataFrame
# Columns: [技能名称, 标准问题, 标准问题的相似度阈值, 补充用户问法（多个用##分隔）, 机器人回答(多个用"##"分隔）]
# Index: []

# %%
skill=''
question=''
addition=''
answer=''
is_add=0
for index,row in ylk_formal.iterrows():
    #print(index,row['多层级的问题类别(由  "|" 分开)'])
    #isnan=pd.isna(row['多层级的问题类别(由  "|" 分开)'])
    isnan=pd.isna(row['分类'])
    if not isnan:
        #结束上一轮
        if (is_add==0):
            new=new.append([{'技能名称':skill,'标准问题':question,'标准问题的相似度阈值':0.3,'机器人回答(多个用"##"分隔）':answer}],ignore_index = True)
        else:
            new=new.append([{'技能名称':skill,'标准问题':question,'标准问题的相似度阈值':0.3,'补充用户问法（多个用##分隔）':addition[2:],'机器人回答(多个用"##"分隔）':answer}],ignore_index = True)
        is_add=0
        #新一轮
        skill=row['分类']
        question=row['问题']
        addition=''
        answer=row['答案']
    else:
        is_add=1
        #print(row['相似问题'])
        addition+='##'+row['相似问题']
new.ix[1:]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#        技能名称                        ...                                                           机器人回答(多个用"##"分隔）
# 1      疫情相关                        ...                          国务院办公厅将对收到的问题线索和意见建议进行汇总整理，督促有关地方、部门及时处理。对涉及缓报...
# ...

# %%
new.ix[1:]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#        技能名称                        ...                                                           机器人回答(多个用"##"分隔）
# 1      疫情相关                        ...                          国务院办公厅将对收到的问题线索和意见建议进行汇总整理，督促有关地方、部门及时处理。对涉及缓报...
# 2      疫情相关                        ...                          新型冠状病毒感染肺炎的确诊、疑似、密切接触者以及无法排除的发热者，目前还没有得到隔离收治的人...
# 3      疫情相关                        ...                          为在疫情期间帮助大家预防与减轻疫情所致的心理困顿，中国政府网联合健康中国推出了全国心理援助热...
# 4      疫情相关                        ...                          为了让广大民众及时知晓周围疫情信息，并有针对性地采取防控措施，遏制疫情扩散，腾讯地图正式上线...
# ...

# %%
new.ix[1:].to_excel('疫战语料库整理版.xlsx',index=None)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
new.ix[1:].ix[540:550]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#      技能名称                        ...                                                           机器人回答(多个用"##"分隔）
# 540  政策法规                        ...                          受到限制。《传染病防治法》第十六条规定，传染病病人、病原携带者和疑似传染病病人，在治愈前或者...
# 541  政策法规                        ...                          需要。未复工期间，用人单位需要妥善处理劳动合同续订事宜。对于劳动合同的续订问题，用人单位可与...
# 542  政策法规                        ...                          原则上以劳动合同履行地的有关规定为准，除非用人单位注册地的标准高于劳动合同履行地的标准，且用...
# 543  政策法规                        ...                          建议用人单位充分与员工协商，达成协商一致：（1）法定/福利年休假/倒休：优先安排员工休法定年...
# ...

# %%
ylk_formal.columns
# Out:
# Index(['多层级的问题类别(由  "|" 分开)', '地区(多个地区则用 "|" 分开)', '问题ID', '标准问', '扩展问',
#        '是否发布', '渠道1(多个渠道支持则用 "|" 分开)', '答案1'],
#       dtype='object')

# %%
import math

# %%
pd.isna(ylk_formal.ix[1]['多层级的问题类别(由  "|" 分开)'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# True

# %%
import pandas as pd
ylk_new=pd.read_excel('my_Hackathon_2020/问答机器人语料库.xlsx',index_col=None)

# %%
ylk_new.head(10)
# Out:
#   技能名称                标准问题 标准问题的相似度阈值  补充用户问法（多个用##分隔）    ...     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0    1         冠状病毒属于什么病毒？        NaN              NaN    ...            NaN        NaN        NaN        NaN
# 1  NaN         冠状病毒的病因是什么？        NaN  冠状病毒是一种急性传染性疾病吗    ...            NaN        NaN        NaN        NaN
# 2  NaN   人感染新型冠状病毒后会有什么症状？        NaN              NaN    ...            NaN        NaN        NaN        NaN
# 3  NaN  新型冠状病毒可以在人与人之间传播吗？        NaN              NaN    ...            NaN        NaN        NaN        NaN
# 4  NaN    目前有针对新型冠状病毒的疫苗吗？        NaN              NaN    ...            NaN        NaN        NaN        NaN
# 5  NaN    有针对新型冠状病毒的治疗方法吗？        NaN              NaN    ...            NaN        NaN        NaN        NaN
# 6  NaN  医护人员会受到新型冠状病毒的威胁吗？        NaN              NaN    ...            NaN        NaN        NaN        NaN
# ...

# %%
ylk_new=ylk_new.ix[:,:5]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
ylk_new.head(8)
# Out:
#   技能名称                        ...                                                           机器人回答(多个用"##"分隔）
# 0    1                        ...                          冠状病毒属于单股正链RNA病毒。\n既往已知感染人的冠状病毒有6种，即HCoV-229E、H...
# 1  NaN                        ...                          新型冠状病毒肺炎是一种急性传染性疾病。\n主要是由2019新型冠状病毒（2019-nCoV）...
# 2  NaN                        ...                          人感染新型冠状病毒后的症状严重程度取决于病毒的类型以及人体的免疫水平，常见的有发热、咳嗽、呼...
# 3  NaN                        ...                             新型冠状病毒是可以在人与人之间传播的，传播通常发生在在家庭、工作场所、人群密集区域或医院等。
# 4  NaN                        ...                                    目前没有针对新型冠状病毒的疫苗，新发疾病可能需要较长时间才能研发出接种的疫苗。
# 5  NaN                        ...                                对于由新型冠状病毒感染引起的疾病，目前没有特效的治疗方法，临床治疗以对症支持治疗为主。
# 6  NaN                        ...                          医护人员需要与患者密切接触，更容易受到新型冠状病毒的感染威胁。因此，世界卫生组织（WHO）建...
# 7  NaN                        ...                                                                        NaN
# ...

# %%
ylk_new.columns
# Out:
# Index(['技能名称', '标准问题', '标准问题的相似度阈值', '补充用户问法（多个用##分隔）', '机器人回答(多个用"##"分隔）'], dtype='object')

# %%
new=pd.DataFrame(columns=ylk_new.columns)

# %%
new
# Out:
# Empty DataFrame
# Columns: [技能名称, 标准问题, 标准问题的相似度阈值, 补充用户问法（多个用##分隔）, 机器人回答(多个用"##"分隔）]
# Index: []

# %%
new.append([{'技能名称':1,'标准问题':2,'标准问题的相似度阈值':3,'补充用户问法（多个用##分隔）':4,'机器人回答(多个用"##"分隔）':5}])
# Out:
#   技能名称 标准问题 标准问题的相似度阈值 补充用户问法（多个用##分隔） 机器人回答(多个用"##"分隔）
# 0    1    2          3               4                5

# %%
new
# Out:
# Empty DataFrame
# Columns: [技能名称, 标准问题, 标准问题的相似度阈值, 补充用户问法（多个用##分隔）, 机器人回答(多个用"##"分隔）]
# Index: []
